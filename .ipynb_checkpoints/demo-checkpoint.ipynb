# %% [markdown]
# # Cloud Probability API — Demo
# Estimación de probabilidad de nubosidad sobre **Villa Carlos Paz, Argentina**
# usando datos históricos de Sentinel-2 (COPERNICUS/S2_CLOUD_PROBABILITY).

# %%
# Instalar dependencias (solo necesario en Colab)
# !pip install earthengine-api geemap matplotlib

# %%
import ee

# Autenticación: ejecutar una sola vez por sesión
ee.Authenticate(auth_mode='notebook')
ee.Initialize(project='ee-test-satelite-img-proc')  # reemplazar con tu proyecto GEE

# %%
from datetime import datetime
from cloud_probability_api import CloudProbabilityAPI

# Región: Villa Carlos Paz (bounding box)
region = ee.Geometry.Rectangle([-64.55, -31.45, -64.35, -31.30])

api = CloudProbabilityAPI(region=region, start_year=2019, end_year=2024)

# %% [markdown]
# ## 1. Probabilidad de nubosidad para una fecha objetivo

# %%
target = datetime(2024, 8, 15)   # 15 de enero

prob = api.get_cloud_probability(target, window_days=15)
usable_prob = api.get_usable_image_probability(target, window_days=3, max_clouds=10.0)
print(f"Nubosidad esperada el {target.strftime('%d %b')}:")
print(f"  Media : {prob['mean']:.1f}%")
print(f"  Std   : {prob['std']:.1f}%")

print(f"  P25 (Días más despejados) : {prob['p25']:.1f}%")
print(f"  Mediana (Lo típico)       : {prob['median']:.1f}%")
print(f"  P75 (Días más nublados)   : {prob['p75']:.1f}%")
print("-" * 40)
print(f"  Prob. de imagen útil (≤20% nubes): {usable_prob:.1f}%")
# Out:
# Nubosidad esperada el 15 Aug:
#   Media : 24.3%
#   Std   : 37.9%
#   P25 (Días más despejados) : 0.0%
#   Mediana (Lo típico)       : 0.0%
#   P75 (Días más nublados)   : 47.2%
# ----------------------------------------
#   Prob. de imagen útil (≤20% nubes): 71.4%

# %% [markdown]
# ## 2. Imágenes históricas más representativas

# %%
images = api.get_similar_images(target, n=5, window_days=3)

print(f"Top-5 imágenes más cercanas a la nubosidad esperada ({prob['mean']:.1f}%):\n")
for feat in images:
    props = feat['properties']
    print(f"  {feat['id'].split('/')[-1]}  →  {props['cloud_percentage']:.1f}% nubosidad")

import geemap

best_image_id = images[0]['id']
best_image = ee.Image(best_image_id)

print(f"Downloading {best_image_id}...")

geemap.ee_export_image(
    best_image.select('probability'), 
    filename="best_cloud_mask.tif",
    scale=100, 
    region=region,
    file_per_band=False
)
print("Download complete!")
# Out:
# Top-5 imágenes más cercanas a la nubosidad esperada (24.3%):
#
#   20240816T140709_20240816T141925_T20JLL  →  15.1% nubosidad
#   20190816T142049_20190816T142351_T20JLL  →  0.1% nubosidad
#   20190813T141049_20190813T142051_T20JLL  →  0.0% nubosidad
#   20200812T141051_20200812T141052_T20JLL  →  0.0% nubosidad
#   20200815T141741_20200815T142541_T20JLL  →  0.0% nubosidad
# Downloading COPERNICUS/S2_CLOUD_PROBABILITY/20240816T140709_20240816T141925_T20JLL...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-test-satelite-img-proc/thumbnails/3e2d1db84230ae545c90186b53e70378-b778536aafa28f6f1c2ad9bb3d0237c5:getPixels
# Please wait ...
# Data downloaded to c:\Users\Admin\Desktop\REPOS-ITBA\cloud-coverage-analysis\best_cloud_mask.tif
# Download complete!

# %% [markdown]
# ## 3. Serie temporal (bonus)

# %%
api.plot_time_series(target, window_days=15)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## 4. Mapa interactivo (bonus)

# %%
m = api.visualize(target, n=3, window_days=15)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# Create UI elements
date_picker = widgets.DatePicker(description='Target Date', value=datetime(2024, 1, 15))
window_slider = widgets.IntSlider(value=15, min=5, max=30, step=1, description='Window (± Days):')
threshold_slider = widgets.FloatSlider(value=20.0, min=5.0, max=50.0, step=1.0, description='Max Clouds %:')
button = widgets.Button(description='Run Analysis', button_style='primary')
output = widgets.Output()

def on_button_clicked(b):
    with output:
        clear_output()
        target_dt = datetime.combine(date_picker.value, datetime.min.time())
        
        prob = api.get_cloud_probability(target_dt, window_days=window_slider.value)
        usable = api.get_usable_image_probability(target_dt, window_days=window_slider.value, max_clouds=threshold_slider.value)
        
        print(f"--- Results for {target_dt.strftime('%d %b')} ---")
        print(f"  Media : {prob['mean']:.1f}%")
        print(f"  Std   : {prob['std']:.1f}%")
        print(f"  P25 (Días más despejados) : {prob['p25']:.1f}%")
        print(f"  Mediana (Lo típico)       : {prob['median']:.1f}%")
        print(f"  P75 (Días más nublados)   : {prob['p75']:.1f}%")
        print(f"  Prob. de imagen útil      : {usable:.1f}%")
        print(f"Nubosidad esperada el {target.strftime('%d %b')}:")

        print(f"  Prob. de imagen útil (≤20% nubes): {usable_prob:.1f}%")

button.on_click(on_button_clicked)

# Display the UI
display(widgets.VBox([date_picker, window_slider, threshold_slider, button, output]))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# VBox(children=(DatePicker(value=datetime.datetime(2024, 1, 15, 0, 0), description='Target Date', step=1), IntS…

# %%
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
usable_probs = []

print("Generating annual cloud profile...")
for month in range(1, 13):
    test_date = datetime(2023, month, 3)
    prob = api.get_usable_image_probability(test_date, window_days=3, max_clouds=10.0)
    usable_probs.append(prob)

fig, ax = plt.subplots(figsize=(10, 4))
bars = ax.bar(months, usable_probs, color='skyblue', edgecolor='black')
ax.set_ylabel("Probability of Clear Image (<20% clouds)")
ax.set_title("Annual Clear-Sky Probability Profile")
ax.set_ylim(0, 100)

for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 2, f"{yval:.1f}%", ha='center', va='bottom', fontsize=9)

plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating annual cloud profile...

# %%
import os
import webbrowser
import ee
import folium
import folium.plugins as plugins

best_image_feat = images[0] 
best_image_id = best_image_feat['id']
cloud_prob_img = ee.Image(best_image_id)

l2a_id = best_image_id.replace('COPERNICUS/S2_CLOUD_PROBABILITY', 'COPERNICUS/S2_SR_HARMONIZED')
true_color_img = ee.Image(l2a_id)

vis_true_color = {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}
vis_cloud = {'bands': ['probability'], 'min': 0, 'max': 100, 'palette': ['000000', 'FFFFFF']}

left_dict = true_color_img.getMapId(vis_true_color)
left_url = left_dict['tile_fetcher'].url_format

right_dict = cloud_prob_img.getMapId(vis_cloud)
right_url = right_dict['tile_fetcher'].url_format

m = folium.Map(
    location=[-31.375, -64.45], 
    zoom_start=12, 
    tiles='https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}', 
    attr='Google'
)

left_layer = folium.TileLayer(
    tiles=left_url,
    attr='Google Earth Engine',
    name='True Color',
    overlay=True
).add_to(m)

right_layer = folium.TileLayer(
    tiles=right_url,
    attr='Google Earth Engine',
    name='Cloud Probability',
    overlay=True
).add_to(m)

plugins.SideBySideLayers(left_layer, right_layer).add_to(m)

html_filename = "pure_folium_slider.html"
m.save(html_filename)

file_path = 'file://' + os.path.realpath(html_filename)
print("Opening pure Folium swipe map in browser...")

webbrowser.open(file_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Opening pure Folium swipe map in browser...
# True

# %%
import ee
import geemap
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt

# 1. Create the Map
Map2 = geemap.Map(center=[-31.375, -64.45], zoom=12)
Map2.addLayer(region, {}, 'Villa Carlos Paz', opacity=0.3)

# Filter the collection for the 15-day window
collection = api._filter_by_date_window(target, window_days=15)

# Add the mean cloud probability as a visual reference on the map
mean_img = collection.mean()
Map2.addLayer(mean_img, {'min': 0, 'max': 100, 'palette': ['blue', 'white']}, 'Mean Clouds')

# 2. Create an empty output space BELOW the map for our charts to appear
out = widgets.Output()

# 3. Define what happens when you click the map
def on_click(**kwargs):
    # Check if the interaction was a mouse click
    if kwargs.get('type') == 'click':
        # ipyleaflet returns coordinates in [lat, lon] order
        lat, lon = kwargs.get('coordinates')
        point = ee.Geometry.Point([lon, lat])
        
        with out:
            # Clear the old chart and print a loading message
            out.clear_output(wait=True)
            print(f"Fetching cloud history for Longitude: {lon:.4f}, Latitude: {lat:.4f}...")
            
            try:
                # Tell Google Earth Engine to extract the pixel value for every date
                def extract_data(img):
                    val = img.reduceRegion(
                        reducer=ee.Reducer.first(), 
                        geometry=point, 
                        scale=api.DEFAULT_SCALE
                    ).get('probability')
                    
                    date = img.date().format('YYYY-MM-dd')
                    return ee.Feature(None, {'date': date, 'probability': val})
                
                # Run the extraction and download the data to Python
                timeseries = ee.FeatureCollection(collection.map(extract_data)).getInfo()['features']
                
                # Clean the data
                dates = []
                probs = []
                for f in timeseries:
                    props = f['properties']
                    if props.get('probability') is not None:
                        dates.append(props['date'])
                        probs.append(props['probability'])
                
                if not dates:
                    print("No satellite data available at this exact pixel.")
                    return

                # Draw the Matplotlib chart
                fig, ax = plt.subplots(figsize=(8, 3))
                ax.plot(dates, probs, marker='o', color='royalblue', linestyle='-')
                ax.set_title(f'Cloud Probability History')
                ax.set_ylim(-5, 105)
                ax.set_ylabel('Probability (%)')
                plt.xticks(rotation=45, ha='right')
                plt.grid(True, linestyle='--', alpha=0.6)
                plt.tight_layout()
                plt.show()
                
            except Exception as e:
                print(f"Error fetching data: {e}")

# 4. Attach the click event to the map
Map2.on_interaction(on_click)

print("Map ready! Click anywhere on the map to generate a chart below.")
display(Map2)
display(out)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map ready! Click anywhere on the map to generate a chart below.
# Map(center=[-31.375, -64.45], controls=(WidgetControl(options=['position', 'transparent_bg'], position='toprig…
# Output()

# %%
video_args = {
    'dimensions': 600,
    'region': region,
    'framesPerSecond': 2,
    'crs': 'EPSG:3857',
    'min': 0.0,
    'max': 100.0,
    'palette': ['blue', 'white']
}

print("Generating Timelapse GIF (This may take a minute...)")
saved_gif = geemap.download_ee_video(collection, video_args, 'cloud_timelapse.gif')

from IPython.display import Image
Image('cloud_timelapse.gif')
